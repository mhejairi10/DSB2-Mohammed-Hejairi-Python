# %% [markdown]
# ## Code Cell

# %%
2+4
# Out:
# 6

# %% [markdown]
# # Markdown Cheat Sheet
#
# Thanks for visiting [The Markdown Guide](https://www.markdownguide.org)!
#
# This Markdown cheat sheet provides a quick overview of all the Markdown syntax elements. It can’t cover every edge case, so if you need more information about any of these elements, refer to the reference guides for [basic syntax](https://www.markdownguide.org/basic-syntax/) and [extended syntax](https://www.markdownguide.org/extended-syntax/).

# %% [markdown]
# ## Basic Syntax
#
# These are the elements outlined in John Gruber’s original design document. All Markdown applications support these elements.

# %% [markdown]
# ### Headings:

# %% [markdown]
# # Heading 1
#
# ## Heading 2
#
# ### Heading 3
#
# #### Heading 4

# %% [markdown]
# ### Bold
#
# **bold text**

# %% [markdown]
# ### Italic
#
# *italic text*

# %% [markdown]
# ### Strikethrough
#
# ~~The world is flat.~~

# %% [markdown]
# ### Blockquote
#
# > blockquote

# %% [markdown]
# ### Ordered List
#
# 1. First item
# 2. Second item
# 3. Third item

# %% [markdown]
# ### Unordered List
#
# - Main item 1
#     - Subitem A
#     - Subitem B
# - Main item 2
#     1. Subitem 1
#     2. Subitem 2

# %% [markdown]
# ### Table
#
# | Name | Age |
# | ----------- | ----------- |
# | Mohammed Aref | 22 |
# | Taha Ahmed | 24 |

# %% [markdown]
# ### Task List
#
# - [x] Write the press release
# - [x] Update the website
# - [ ] Contact the media

# %% [markdown]
# ### Code
#
# `This is my code here`

# %% [markdown]
# ### Code SQL or Python
#
# ```SQL
# select *
# from table
# Where column1="test"
# ```

# %% [markdown]
# ### Horizontal Rule
#
# ---
# This is DAB course

# %% [markdown]
# ### Link
#
# [Markdown Guide](https://www.markdownguide.org)

# %% [markdown]
# ### Image 1 (link):
# 1. Find an image in any site.
# 2. right click on the image then select `Copy image address`
# 3. paste it between the paranthesis
#
# ![test image](https://www.markdownguide.org/assets/images/tux.png)

# %% [markdown]
# ### Image 2 Resizable (link) :
#
# 1. Find an image in the following site:
# (https://hugovk.github.io/python-logos/?featured_on=pythonbytes)
# 2. right click on the image then select `Copy image address`
# 3. Then paste it in the below markdown code as a `src`
#
#
# <img src="https://hugovk.github.io/python-logos/img/PyConZA.png" width="20%">

# %% [markdown]
# ### Image 3 (copy image and paste directly):
# 1. Find an image in any site.
# 2. right click on the image then select `copy image`
# 3. paste it here in the cell directly
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Emoji
#
# Simply copy   paste your emojis 🤙😁👍
#
# That is so funny! 😂

# %% [markdown]
# ### Subscript
#
# H<sub>2</sub>O

# %% [markdown]
# ### Superscript
#
# X<sup>2</sup>

# %% [markdown]
# ### Alert Boxes

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed. Typically also used to display warning messages.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Success:</b> This alert box indicates a successful or positive action.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Danger:</b> This alert box indicates a dangerous or potentially negative action.
# </div>

# %% [markdown]
# ### Mathematics

# %% [markdown]
# $$
#   \int_0^\infty \frac{x^3}{e^x-1}\,dx = \frac{\pi^4}{15}
# $$

# %% [markdown]
# $$
#   w_{t+1} = (1 + r_{t+1}) s(w_t) + y_{t+1}
# $$
