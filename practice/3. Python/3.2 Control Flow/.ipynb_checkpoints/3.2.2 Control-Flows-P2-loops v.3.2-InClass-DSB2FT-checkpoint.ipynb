# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# #  Python Control Flows Part 2: loops
#
#
# ---
# \
# *Last updated 9-1-2025*
# \
# *Tested on python version 3.13.1*

# %% [markdown]
# ### LEARNING OBJECTIVES
#
# - Formulate for and while loops
# - Iterate using for loops
# - Iterate using while loops

# %% [markdown]
# ## How would you code without Loops?!
#
# Imagine that we have a list of colors and we want to print each one of them:
#
# Does this seem sustainable?

# %%
# we have a list of colors and we want to print each one of them
colors = ["red", "orange", "yellow"]

# %% [markdown]
# Does the above code seem sustainable?

# %% [markdown]
# - How about if you want to calculate the price multiplied by the tax for each number in the following list and save the result in a new list called total?

# %%
tax = 1.15
total=[]
price=[34,64,90,22,65,898,34]

# let's do it together





print(total)

# %% [markdown]
# <a name="for_and_while_loops"></a>
# ## Introduction: for and while loops
#
# The for statement is used to iterate over the elements of a sequence, that means any kind of iterable object like strings, lists, tuples, dictionaries and so on. It's
# used when you have a piece of code which you want to repeat a certain number of times.
#
# The while loop tells the computer to do something as long as a condition is met.
# A while loop consists of a block of code and a condition. The condition
# is evaluated, and if the condition is true, the code within the
# block is executed. This repeats until the condition becomes false.

# %% [markdown]
# <a name="demo_for"></a>
# ## for Loops
#
# One of the primary purposes of using a programming language is to automate repetitive tasks. One such means in Python is the `for` loop.
#
# The `for` loop allows you to perform a task repeatedly on every element within an object, such as every name in a list.
#
# The general syntax for a **for loop** is indicated below:
#
# ```python
#     for iterator_name in iterating_sequence:
#         …statements…
# ```

# %% [markdown]
# - This process of cycling through a list item by item is known as `iteration`

# %%
# Example on iterating over a list and print each item in it

# %% [markdown]
# This is a for loop. It has the heading starting with `for`, followed by a
# variable name (myitems in this case), the word `in`, some sequence, and a final colon.
# As with function definitions and other heading lines, the colon at the end of
# the line indicates that a consistently indented block of statements follows
# to complete the for loop.

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="700">
# </div>

# %% [markdown]
# - Another example:
# Let's say we wanted to print each of the names in the list, as well as "is Awesome!"

# %%
names = ['Mohammed', 'Ahmed', 'Jasem']

# %% [markdown]
# - Let's try to solve the previous example with tax calculation with total price using `for` loop

# %%
tax = 1.15
total=[]
price=[34,64,90,22,65,898,34]

# let's do it together



print(total)

# %% [markdown]
# ### Tip💡
# - Try the following site to visualize the execution order in Python
#
# https://pythontutor.com/render.html#mode=edit

# %% [markdown]
# ### Using the range() Function
# Because for loops require an iterable, it's common to use the range() function to automatically generate a list of numbers over which to iterate

# %%
# Example using range()

# %%
# Example using range() doing an operation in each loop

# %%
# simple repeat loop

# %%
# Loop using a start and an end of a range

# %%
# loop with a range with three paramenters

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Loop through a list

# %%
# Iterate Through a list
# print each item in the following list

teas = ['earl grey', 'darjeeling', 'english breakfast', 'lapsang souchong', 
        'oolong', 'kombucha', 'green tea']

# %% [markdown]
# ### Loop through a string
#
# Using a for loop to go through the letters in a word

# %%
# Iterate Through a string
# print each letter in the following string

word = 'computer'

# %% [markdown]
# ### Loop with Indices (To modify a list)
#
# If you want to actually modify a list while looping, you must use indices:

# %%
# modify the following list by multiplying each item by 2, save the result back to the same list
numbers = [5,7,2,8]


    
print(numbers)

# %% [markdown]
# ### Looping over Dictionaries

# %%
grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}

# %%
# recall how to access the keys and values in a dictionary

print("\n Dictionary keys:",grades.keys())

print("\n Dictionary Values:",grades.values())

print("\n Dictionary items:",grades.items())
# Out:
#  Dictionary keys: dict_keys(['a', 'b', 'c', 'd'])
#
#  Dictionary Values: dict_values(['excellent', 'Very good', 'good', 'bad'])
#
#  Dictionary items: dict_items([('a', 'excellent'), ('b', 'Very good'), ('c', 'good'), ('d', 'bad')])

# %% [markdown]
# #### *Example1*: Iterate Through a Dictionary `keys`

# %% [markdown]
# - The default is to loop over the `keys` if you didn't specify which part to loop over in the dictionary, see below example

# %%
# Iterate Through a Dictionary example.1

grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}


# or alternativaly, which will do the same result (The default to loop over dictionary keys)

# %% [markdown]
# #### *Example2*: Iterate Through a Dictionary `values`

# %%
# Iterate Through a Dictionary example.2

grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}

# %% [markdown]
# #### *Example3*: Iterate Through a Dictionary `items`

# %%
# Iterate Through a Dictionary example.3

grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}

# %% [markdown]
# #### *Example4*: Iterate Through a Dictionary `items` using two loop variables

# %%
# Iterate Through a Dictionary example.4

grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}

# %% [markdown]
# #### *Example5*: Iterate Through a Dictionary using the key index

# %%
# Iterate Through a Dictionary example.5

grades = {"a":"excellent","b":"Very good","c":"good","d":"bad"}

# %%
# the following will give an error 
# you are referencing the keys but expect 2 outputs
for k,v in grades.keys():
    print(k,v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # the following will give an error
#       2 # you are referencing the keys but expect 2 outputs
# ----> 3 for k,v in grades.keys():
#       4     print(k,v)
#
# TypeError: cannot unpack non-iterable int object

# %% [markdown]
# ### Nested Loops
# Just as it’s possible to nest data structures inside of each other, it is also possible to put loops inside of other loops.
#
# ```
# Do a loop to print similar output
#     2 times 2 = 4
#     2 times 3 = 6
#     2 times 4 = 8
#     3 times 2 = 6
#     3 times 3 = 9
#     3 times 4 = 12
# ```

# %%
# example on nested loop

# %% [markdown]
# ## Using `enumerate` function (Optional)
# An enumerate object is an iterator of tuples with index and element pairs from the original iterable. That allows us to keep track of the number of iterations (loops) in a loop along with its value.

# %%
# Let's try out the following:
mylist= ["a","b","c","d","e","f","h","i"]

# Let's use enumerate in a loop

# %% [markdown]
# ## List Comprehension (Optional)
#
#
# The way we've been working with for loops works fine, but in Python there's a way to do this more succinctly using list comprehension. Listcomps are also optimized in Python, meaning they are also often the fastest way to solve a problem.

# %% [markdown]
# ![image.png](attachment:07629cd9-1034-4558-a5b1-7cf991c72225.png)

# %%
# example for list comprehension
# create a new list contains each item in the following list multiplied by 2
numbers = [1,2,3,4,5]

# %% [markdown]
# - Assume we want to remove all the occurances of number 900 from the following list:

# %%
my_list=[23,34,76,900,2,52,85,25,97,900,225,743,83,12,900,3,85,875,24,6,900,34,62,11,42]

# %% [markdown]
# - Using the normal for loop:

# %%
# let's do it together

# %% [markdown]
# - Using list comprehension:

# %%
my_list=[23,34,76,900,2,52,85,25,97,900,225,743,83,12,900,3,85,875,24,6,900,34,62,11,42]

# %%
# let's do it together using list comprehension

# %% [markdown]
# - ##### Do you remember the previous tax calculation? let's do it using list comprehension
# ```python
#
#             tax = 1.15
#             total=[]
#             price=[34,64,90,22,65,898,34,54,66,34,89]
#
#             for x in price:
#                 total.append(x*tax)
#
#
#             print(total)
# ```

# %%
# let's do it together using list comprehension

# %% [markdown]
# <a name="demo_while"></a>
# ## `while` loops
#
# The general syntax for a **while loop** is indicated below:
#
# ```python
#     while condition:
#         …statements…
# ```
#
# The syntax includes the following parts:
# * in the first line
#     * the keyword **`while`**
#     * followed by a condition which evaluates to `true` or `false`
#     * followed by a colon
# * an indented code block including all statements to be executed if the condition evaluates to true
#
# Once the statements have been executed, the condition will be checked again, and if it still holds, the statements will be executed once more and so on. This means that if the condition is met initially but not modified by any of the statements it will simply keep running, so be careful.

# %% [markdown]
# <div>
# <img src="attachment:image-3.png" width="700">
# </div>

# %% [markdown]
# Let's create a simple counter using a while loop.

# %%
# print the number starting from 0 until you reach 4

# %% [markdown]
# Another counter using a while loop

# %% [markdown]
# And one more...
#
# Take an input string from the user and print it until he writes the word `stop`

# %% [markdown]
# This while loop will stop when the user types "stop".
#
# Remember, a while loop runs until the condition is False. The problem is,
# sometimes they don't stop. To avoid this, here are some rules to follow:
#
# * Make sure that you use while-loops carefully. Usually a for-loop is better.
# * Review your while statements and make sure that the boolean test will
#    become False at some point.
# * When in doubt, print out your test variable at the top and bottom of the
#    while-loop to see what it's doing.

# %% [markdown]
# ### Discussion: What Will This Code Do?
# ```python
#         number=1
#         while number>0:
#             number=number+1
#             print(number)
# ```

# %% [markdown]
# ### <font color='red'> Be careful of infinite loops, it will run forever and hang your machine
# ```python
#                 #example of an infinite loop
#                 x=0
#                 while x<10:
#                     test="be careful"
#
#
# ```

# %% [markdown]
# ### For vs. While: Which One to Use?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Discussions (For or While?)

# %% [markdown]
# - Look through a list to find the largest number.
# - Flip a coin until heads shows up three times in a row.
# - Print every value in a list.
# - Check the weather every five seconds until it rains.

# %% [markdown]
# <a name="ind-practice_for"></a>
# ## Independent Practice: for and while loops
#
# Now, try creating a few for loops on your own with the exercises

# %% [markdown]
# <a name="conclusion"></a>
# ## Conclusion
#
# After this lesson you should be able to describe
# - when a for loop or a while loop are useful
# - what are the differences between for and while loops
# - potential dangers with while loops and what you can do to avoid them
